# %%
import numpy as np
import pandas as pd
data=pd.read_csv("matches.csv")
data
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# ### top 5 batsman in terms of runs scored

# %%
delivery=pd.read_csv("deliveries.csv")
delivery
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
# to display only batsman and runs
batsman=delivery.groupby('batsman')
batsman['batsman_runs'].sum().sort_values(ascending=False).head()
# Out:
# batsman
# SK Raina     4548
# V Kohli      4423
# RG Sharma    4207
# G Gambhir    4132
# DA Warner    4014
# Name: batsman_runs, dtype: int64

# %%
# to display batsman with all their details
batsman=delivery.groupby('batsman')
batsman.sum('batsman_runs').sort_values('batsman_runs',ascending=False).head()
# Out:
#            match_id  inning   over   ball  is_super_over  wide_runs  bye_runs  \
# batsman
# SK Raina    1079285    4748  32746  12256              3        124         0
# V Kohli     1304291    5112  33426  12284              2        110         5
# RG Sharma   1081920    4822  36662  11601              0         66         2
# G Gambhir   1072760    5510  23650  12313              0        151        10
# DA Warner   1085379    4258  21153  10188              1        108        23
#
#            legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# batsman
# SK Raina            57           16             0          4548         197
# V Kohli             39           11             0          4423         165
# RG Sharma           48           11             0          4207         127
# G Gambhir           85           10             0          4132         256
# DA Warner           52           16             0          4014         199
#
# ...

# %%
batsman.size()
# Out:
# batsman
# A Ashish Reddy     196
# A Chandila           7
# A Chopra            75
# A Choudhary         20
# A Flintoff          57
#                   ...
# YV Takawale        183
# Yashpal Singh       67
# Younis Khan          7
# Yuvraj Singh      2050
# Z Khan             141
# Length: 461, dtype: int64

# %%
data1=data.groupby("team1")
data1.get_group("Royal Challengers Bangalore")
# Out:
#       id  season        city        date                        team1  \
# 4      5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 7      8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 11    12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 19    20    2017      Rajkot  2017-04-18  Royal Challengers Bangalore
# 29    30    2017   Bangalore  2017-04-27  Royal Challengers Bangalore
# ..   ...     ...         ...         ...                          ...
# 605  606    2016   Bangalore  2016-05-02  Royal Challengers Bangalore
# 614  615    2016  Chandigarh  2016-05-09  Royal Challengers Bangalore
# 616  617    2016   Bangalore  2016-05-11  Royal Challengers Bangalore
# 619  620    2016   Bangalore  2016-05-14  Royal Challengers Bangalore
# 625  626    2016   Bangalore  2016-05-18  Royal Challengers Bangalore
#
#                      team2                  toss_winner toss_decision  result  \
# ...

# %% [markdown]
# ### Each team is won by how many runs

# %%
data1["win_by_runs"].sum()
# Out:
# team1
# Chennai Super Kings            1594
# Deccan Chargers                 421
# Delhi Daredevils                596
# Gujarat Lions                     1
# Kings XI Punjab                 867
# Kochi Tuskers Kerala             23
# Kolkata Knight Riders           879
# Mumbai Indians                 1532
# Pune Warriors                   139
# Rajasthan Royals                821
# Rising Pune Supergiant          123
# Rising Pune Supergiants           0
# Royal Challengers Bangalore    1196
# Sunrisers Hyderabad             510
# Name: win_by_runs, dtype: int64

# %% [markdown]
# ### top 5 batsman who scored highest fours

# %%
four=delivery["batsman_runs"]==4

# %%
four
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 150455    False
# 150456    False
# 150457    False
# 150458    False
# 150459     True
# Name: batsman_runs, Length: 150460, dtype: bool

# %%
# total no.of fours 
delivery[four].shape[0]
# Out:
# 17033

# %%
bman=delivery[four].groupby("batsman")

# %%
bman["batsman_runs"].count()
# Out:
# batsman
# A Ashish Reddy     16
# A Chopra            7
# A Choudhary         1
# A Flintoff          5
# A Kumble            3
#                  ...
# YK Pathan         240
# YV Takawale        26
# Yashpal Singh       5
# Yuvraj Singh      205
# Z Khan             11
# Name: batsman_runs, Length: 368, dtype: int64

# %%
bman["batsman_runs"].count().sort_values(ascending=False).head()
# Out:
# batsman
# G Gambhir    484
# SK Raina     402
# DA Warner    401
# S Dhawan     401
# V Kohli      384
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ### highest score of virat kohli against which 3 teams

# %%
vk=delivery["batsman"]=="V Kohli"
vk1=delivery[vk].groupby("bowling_team")

# %%
vk1["batsman_runs"].sum()
# Out:
# bowling_team
# Chennai Super Kings        706
# Deccan Chargers            306
# Delhi Daredevils           661
# Gujarat Lions              283
# Kings XI Punjab            483
# Kochi Tuskers Kerala        50
# Kolkata Knight Riders      391
# Mumbai Indians             447
# Pune Warriors              128
# Rajasthan Royals           258
# Rising Pune Supergiant      83
# Rising Pune Supergiants    188
# Sunrisers Hyderabad        439
# Name: batsman_runs, dtype: int64

# %%
vk1["batsman_runs"].sum().sort_values(ascending=False).head(3)
# Out:
# bowling_team
# Chennai Super Kings    706
# Delhi Daredevils       661
# Kings XI Punjab        483
# Name: batsman_runs, dtype: int64

# %% [markdown]
# ### function to return highest score of batsman against which team

# %%
def run_scored(batsman_name):
    vk=delivery["batsman"]==batsman_name
    vk1=delivery[vk].groupby("bowling_team")
    return vk1["batsman_runs"].sum().sort_values(ascending=False).head(3)

# %%
run_scored("V Kohli")
# Out:
# bowling_team
# Chennai Super Kings    706
# Delhi Daredevils       661
# Kings XI Punjab        483
# Name: batsman_runs, dtype: int64

# %%
run_scored("DA Warner")
# Out:
# bowling_team
# Kolkata Knight Riders          677
# Kings XI Punjab                668
# Royal Challengers Bangalore    569
# Name: batsman_runs, dtype: int64

# %%
run_scored("CH Gayle")
# Out:
# bowling_team
# Kings XI Punjab          797
# Kolkata Knight Riders    532
# Mumbai Indians           469
# Name: batsman_runs, dtype: int64
