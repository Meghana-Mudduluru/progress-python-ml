# %% [markdown]
# ### alphabet_stock_data:

# %% [markdown]
# #### Historical stock prices of Alphabet Inc. (GOOG)
# #### Time Period: April 01, 2020 - October 01, 2020

# %% [markdown]
# #### Description of Dataset:
#
#    * Date: It gives the date of which stocks details are given.
#    * Open: It gives the opening price of stock on that date.
#    * High: It gives the highest price to which the stock ascened on that day.
#    * Low: It gives the highest price to which the stock plummeted on that day.
#    * Close: It gives the closing price of stock on that date.
#    * Volume: It gives the amount of stock traded on that date.
#    * Adjusted Close: An adjusted closing price is a stock’s closing price on any given day of trading that has been amended to include any distributions and corporate actions that occurred at any time prior to the next day’s open.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("alphabet_stock_data.csv")

# %%
#data.to_string()#-----to print the entire dataset

# %%
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# ...

# %% [markdown]
# #### 1. Write a Pandas program to create a line plot of the historical stock prices of Alphabet Inc. between two specific dates.

# %%
newdata=((data['Date']>='2020-04-01') & (data['Date']<='2020-09-30'))

# %%
df=data[newdata]
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2020-04-01  1122.000000  1129.689941  1097.449951  1105.619995
# 1    2020-04-02  1098.260010  1126.859985  1096.400024  1120.839966
# 2    2020-04-03  1119.015015  1123.540039  1079.810059  1097.880005
# 3    2020-04-06  1138.000000  1194.660034  1130.939941  1186.920044
# 4    2020-04-07  1221.000000  1225.000000  1182.229980  1186.510010
# ..          ...          ...          ...          ...          ...
# 122  2020-09-24  1411.030029  1443.708984  1409.849976  1428.290039
# 123  2020-09-25  1432.630005  1450.000000  1413.339966  1444.959961
# 124  2020-09-28  1474.209961  1476.800049  1449.301025  1464.520020
# 125  2020-09-29  1470.390015  1476.662964  1458.805054  1469.329956
# 126  2020-09-30  1466.800049  1489.750000  1459.880005  1469.599976
#
#        Adj Close   Volume
# 0    1105.619995  2343100
# 1    1120.839966  1964900
# 2    1097.880005  2313400
# 3    1186.920044  2664700
# ...

# %%
df.plot(x='Date',y='Close',color='m',fontsize=7,linewidth=2,linestyle='solid')
plt.xlabel('Date')
plt.ylabel('$ Price')
plt.title('Stock prices of Alphabet Inc. between 2020-04-01 & 2020-09-30')
plt.show()

# %% [markdown]
# #### 2.Write a Pandas program to create a line plot of the opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
df1=data.iloc[:,[0,1,4]]

# %%
df1
# Out:
#            Date         Open        Close
# 0    2020-04-01  1122.000000  1105.619995
# 1    2020-04-02  1098.260010  1120.839966
# 2    2020-04-03  1119.015015  1097.880005
# 3    2020-04-06  1138.000000  1186.920044
# 4    2020-04-07  1221.000000  1186.510010
# ..          ...          ...          ...
# 122  2020-09-24  1411.030029  1428.290039
# 123  2020-09-25  1432.630005  1444.959961
# 124  2020-09-28  1474.209961  1464.520020
# 125  2020-09-29  1470.390015  1469.329956
# 126  2020-09-30  1466.800049  1469.599976
#
# [127 rows x 3 columns]

# %%
df1.plot(x='Date',y=['Open','Close'],fontsize=7)
plt.xlabel('Date')
plt.ylabel('$Price')
plt.title('Opening/Closing Stock prices of Alphabet Inc. between 2020-04-01 & 2020-09-30',fontsize=10)
plt.show()

# %% [markdown]
# #### 3.Write a Pandas program to create a bar plot of the trading volume of Alphabet Inc. stock between two specific dates.

# %%
newdata1=((data['Date']>='2020-04-01') & (data['Date']<='2020-04-30'))
df1=data[newdata1]
df1.plot(kind='bar',x='Date',y='Volume',fontsize=5)
plt.xlabel('Date')
plt.ylabel('$Price')
plt.title('Volume of Alphabet Inc. stock between 2020-04-01 & 2020-04-30.')
plt.show()

# %% [markdown]
# #### 4.Write a Pandas program to create a bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
df1.plot(kind='bar',x='Date',y=['Open','Close'],fontsize=5)
plt.xlabel('Date')
plt.ylabel('$Price')
plt.title('Opening,Closing stock prices of Alphabet Inc. stock between 2020-04-01 & 2020-04-30.')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Opening,Closing stock prices of Alphabet Inc. stock between 2020-04-01 & 2020-04-30.')

# %% [markdown]
# #### 5. Write a Pandas program to create a stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
df1.plot(kind='bar',x='Date',y=['Open','Close'],fontsize=5,stacked=True)
plt.xlabel('Date')
plt.ylabel('$Price')
plt.title('Opening,Closing stock prices of Alphabet Inc. stock between 2020-04-01 & 2020-04-30.')
plt.show()

# %% [markdown]
# #### 6. Write a Pandas program to create a horizontal stacked bar plot of opening, closing stock prices of Alphabet Inc. between two specific dates.

# %%
df1.plot(kind='barh',x='Date',y=['Open','Close'],fontsize=5,stacked=True)
plt.xlabel('Date')
plt.ylabel('$Price')
plt.title('Opening,Closing stock prices of Alphabet Inc. stock between 2020-04-01 & 2020-04-30.')
plt.show()

# %% [markdown]
# #### 7. Write a Pandas program to create a histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates

# %%
df.plot(kind='hist',x='Date',y=['Open','Close','High','Low'],alpha=0.5) # alpha used for transparency
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.title('opening, closing, high, low stock prices of Alphabet Inc. stock between 2020-04-01 & 2020-09-30.')
plt.show()

# %% [markdown]
# #### 8. Write a Pandas program to create a stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates

# %%
df.plot(kind='hist',x='Date',y=['Open','Close','High','Low'],stacked=True,bins=20) # alpha used for transparency , by default no of bins are 10
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.title('opening, closing, high, low stock prices of Alphabet Inc. stock between 2020-04-01 & 2020-09-30.')
plt.show()

# %%
# example program to understand the histogram in a better way
# width of each bin=(max value of data-min value of data)/total no of bins
#x=['a','b','c','d','e']
import numpy as np
y=np.array([1,3,4,5,1,3,2,5,3,7,5,6])
x=pd.DataFrame(y)
x.plot(kind='hist',bins=3)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# #### 9. Write a Pandas program to draw a horizontal and cumulative histograms plot of opening stock prices of Alphabet Inc. between two specific dates

# %%
df1.plot(kind='hist',x='Date',y='Open',fontsize=5,orientation='horizontal',cumulative=True)
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.title('Opening stock prices of Alphabet Inc. stock between 2020-04-01 & 2020-04-30.')
plt.show()

# %% [markdown]
# #### 10. Write a Pandas program to create a stacked histograms plot of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates with more bins

# %%
df.plot(kind='hist',x='Date',y=['Open','Close','High','Low'],stacked=True,bins=200) 
plt.xlabel('Date')
plt.ylabel('Frequency')
plt.title('opening, closing, high, low stock prices of Alphabet Inc. stock between 2020-04-01 & 2020-09-30.')
plt.show()

# %% [markdown]
# #### 11. Write a Pandas program to create a stacked histograms plot with more bins of opening, closing, high, low stock prices of Alphabet Inc. between two specific dates

# %%
df2=df[['Open','Close','High','Low']]
df2.hist(bins=10)
# Out:
# array([[<Axes: title={'center': 'Open'}>,
#         <Axes: title={'center': 'Close'}>],
#        [<Axes: title={'center': 'High'}>,
#         <Axes: title={'center': 'Low'}>]], dtype=object)

# %% [markdown]
# #### 12. Write a Pandas program to create a plot of stock price and trading volume of Alphabet Inc. between two specific dates

# %%
fig,ax1=plt.subplots()
ax1.plot(df['Date'],df['Close'])
plt.title('Historical stock prices of Alphabet Inc. stock between 2020-04-01 & 2020-09-30.')
fig,ax2=plt.subplots()
ax2.bar(df['Date'],df['Volume'])
plt.title('Alphabet Inc. Trading volume')
#plt.show()
# Out:
# Text(0.5, 1.0, 'Alphabet Inc. Trading volume')

# %% [markdown]
# #### 13. Write a Pandas program to create a plot of Open, High, Low, Close, Adjusted Closing prices and Volume of Alphabet Inc. between two specific dates

# %%
df.plot(kind='line',x='Date',y=['Open','High','Low','Close','Adj Close','Volume'],fontsize=7,subplots=True) 
plt.xlabel('Date')
#plt.ylabel('Frequency')
plt.suptitle('Open, High, Low, Close, Adjusted Closing prices and Volume of Alphabet Inc. stock between 2020-04-01 & 2020-09-30.')
#plt.show()
# Out:
# Text(0.5, 0.98, 'Open, High, Low, Close, Adjusted Closing prices and Volume of Alphabet Inc. stock between 2020-04-01 & 2020-09-30.')

# %% [markdown]
# #### 14. Write a Pandas program to create a plot of adjusted closing prices, thirty days and forty days simple moving average of Alphabet Inc. between two specific dates
#     A simple moving average (SMA) is a calculation that shows the average price of a security over a set period of time. It's a core indicator in technical analysis and is used to: Determine the direction of a trend, Smooth price data, Trigger trading signals, Establish support and resistance levels, and Identify potential entry and exit points.
#     The formula for calculating a SMA is:
#      SMA=(A1+A2+...+An)/n
#
#     *    An: The price of an asset at period
#     *    n: The number of total periods

# %%
df.plot(x='Date',y='Adj Close',fontsize=7)
plt.grid(axis='both') # plt.grid()
#df['SMA 30']=df.iloc[:,4].mean()
#df['SMA 40']=df.iloc[:,4].mean()
#plt.plot(df['SMA 30'])
#plt.plot(df['SMA 40'])
plt.title('Historical stock prices of Alphabet Inc. between 01-04-2020 to 30-09-2020')
# Out:
# Text(0.5, 1.0, 'Historical stock prices of Alphabet Inc. between 01-04-2020 to 30-09-2020')

# %% [markdown]
# #### 15. Write a Pandas program to create a scatter plot of the trading volume/stock prices of Alphabet Inc. stock between two specific dates

# %%
df.plot(x='Close',y='Volume',kind='scatter')
plt.xlabel('Stock Price')
plt.ylabel('Trading Label')
plt.grid()
plt.title('Trading volume/stock prices of Alphabet Inc. stock between 01-04-2020 to 30-09-2020')
# Out:
# Text(0.5, 1.0, 'Trading volume/stock prices of Alphabet Inc. stock between 01-04-2020 to 30-09-2020')
